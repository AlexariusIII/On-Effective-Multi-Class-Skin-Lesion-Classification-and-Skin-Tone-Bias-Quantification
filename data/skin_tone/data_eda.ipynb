# %%
import pandas as pd

# %%
df = pd.read_csv("skin_tone_data.csv")
df
# Out:
#                image_id     binary multiclass skin_tone    dataset  \
# 0            000001.png  malignant        MEL         C        ddi
# 1            000002.png  malignant        MEL         C        ddi
# 2            000003.png        NaN        NaN         C        ddi
# 3            000004.png  malignant        SCC         C        ddi
# 4            000005.png  malignant        BCC         A        ddi
# ...                 ...        ...        ...       ...        ...
# 32354  ISIC_9988844.jpg  benignant        NEV         A  argentina
# 32355  ISIC_9995847.jpg        NaN        NaN         A  argentina
# 32356  ISIC_9997367.jpg  benignant        ACK         A  argentina
# 32357  ISIC_9998679.jpg  malignant        BCC         A  argentina
# 32358  ISIC_9999251.jpg  benignant        ACK         A  argentina
#
#           image_type     stratify_col
# 0           clinical       C_clinical
# 1           clinical       C_clinical
# 2           clinical       C_clinical
# ...

# %%
df.value_counts("dataset")
# Out:
# dataset
# fp           15956
# scin          8683
# mskcc         4096
# pad           1494
# argentina     1474
# ddi            656
# Name: count, dtype: int64

# %%
df_deduplicated = df.drop_duplicates(subset=['image_id'])
df_deduplicated
# Out:
#                image_id     binary multiclass skin_tone    dataset  \
# 0            000001.png  malignant        MEL         C        ddi
# 1            000002.png  malignant        MEL         C        ddi
# 2            000003.png        NaN        NaN         C        ddi
# 3            000004.png  malignant        SCC         C        ddi
# 4            000005.png  malignant        BCC         A        ddi
# ...                 ...        ...        ...       ...        ...
# 32354  ISIC_9988844.jpg  benignant        NEV         A  argentina
# 32355  ISIC_9995847.jpg        NaN        NaN         A  argentina
# 32356  ISIC_9997367.jpg  benignant        ACK         A  argentina
# 32357  ISIC_9998679.jpg  malignant        BCC         A  argentina
# 32358  ISIC_9999251.jpg  benignant        ACK         A  argentina
#
#           image_type     stratify_col
# 0           clinical       C_clinical
# 1           clinical       C_clinical
# 2           clinical       C_clinical
# ...

# %%
df_deduplicated.value_counts("dataset")
# Out:
# dataset
# fp           15956
# scin          4180
# mskcc         4096
# pad           1494
# argentina     1474
# ddi            656
# Name: count, dtype: int64
